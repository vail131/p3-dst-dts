# %%
# %cd code
# Out:
# /opt/ml/project/team/code

# %%
import json
import regex as re
from attrdict import AttrDict
from string import Template

from collections import defaultdict
from dataclasses import dataclass
from typing import List, Optional, Union, Dict

from prepare import get_data
from data_utils import load_dataset, get_examples_from_dialogues, split_slot

# %%
args = AttrDict(
    train_file_name='train_dials.json',
    data_dir= '/opt/ml/input/data/train_dataset',
    ontology_root='/opt/ml/input/data/train_dataset/edit_ontology_metro.json',
    use_convert_ont=False,
    use_domain_slot='basic',
    use_small_data=False,
)

# %%
data, slot_meta, ontology = get_data(args)
# Out:
# using train: train_dials.json

# %%
examples = get_examples_from_dialogues(
        data, user_first=False, dialogue_level=True, which='all'
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Getting all examples from dialogues', max=7000.0, style=P…

# %%
examples[4]
# Out:
# [DSTInputExample(guid='falling-king-2544:택시_1-0', context_turns=[], current_turn=['', '요청할게 있습니다. 인사동에서 모텔 킹까지 가는 고급택시를 찾고있습니다. '], label=['택시-출발지-인사동', '택시-도착지-모텔 킹', '택시-종류-고급'], before_label=[]),
#  DSTInputExample(guid='falling-king-2544:택시_1-1', context_turns=['', '요청할게 있습니다. 인사동에서 모텔 킹까지 가는 고급택시를 찾고있습니다. '], current_turn=['안녕하세요. 원하시는 출발시간대와 도착시간대가 있으신가요? ', '13시 20분까지 도착만 하면 됩니다. 출발시간은 아무때나 괜찮습니다. '], label=['택시-출발 시간-dontcare', '택시-출발지-인사동', '택시-도착지-모텔 킹', '택시-도착 시간-13:20', '택시-종류-고급'], before_label=['택시-출발지-인사동', '택시-도착지-모텔 킹', '택시-종류-고급']),
#  DSTInputExample(guid='falling-king-2544:택시_1-2', context_turns=['', '요청할게 있습니다. 인사동에서 모텔 킹까지 가는 고급택시를 찾고있습니다. ', '안녕하세요. 원하시는 출발시간대와 도착시간대가 있으신가요? ', '13시 20분까지 도착만 하면 됩니다. 출발시간은 아무때나 괜찮습니다. '], current_turn=['10000원으로 이용하실 수 있는 고급택시가 검색되었습니다. 전화번호는 06837405219 입니다. 더 궁금하신 사항 있으신가요? ', '아니요 감사합니다. '], label=['택시-출발 시간-dontcare', '택시-출발지-인사동', '택시-도착지-모텔 킹', '택시-도착 시간-13:20', '택시-종류-고급'], before_label=['택시-출발 시간-dontcare', '택시-출발지-인사동', '택시-도착지-모텔 킹', '택시-도착 시간-13:20', '택시-종류-고급'])]

# %%
@dataclass
class TurnFeature:
    guid: str
    current_turn: List[str]
    value: str
    before_states: Dict[str, str]
    
    def __repr__(self):
        return f'''
{self.guid}
VAL: {self.value}
SYS: {self.current_turn[0]}
USR: {self.current_turn[1]}
before: {self.before_states}
'''

# %%
guid2examples = {y.guid:y for x in examples for y in x}

# %%
def labels_to_dict(label):
    ret = dict()
    for x in label:
        slot, value = split_slot(x, True)
        ret[slot] = value
    return ret

# %%
slot2guids = defaultdict(list)
for dialogs in examples:
    for example in dialogs:
        before_label_dict = labels_to_dict(example.before_label)

        for slot_value in example.label:
            if slot_value in example.before_label:
                continue
            slot, value = split_slot(slot_value, True)
            slot2guids[slot].append(
                TurnFeature(example.guid, example.current_turn, value, before_label_dict)
            )

# %%
def can_find(pat, turn, no_space):
    if re.search(pat, turn) is not None:
        return True
    if no_space and re.search(''.join(pat.split()), ''.join(turn.split())) is not None:
        return True
    return False

# %%
def show_example(example):
    print(f'guid: {example.guid}')
    print()
    print('------------ HISTORY ------------')
    for i, val in enumerate(example.context_turns):
        who = 'SYS' if i % 2 == 0 else 'USR'
        print(f'{who}: {val}')
    print()
    print('------------ CURRENT ------------')
    for i, val in enumerate(example.current_turn):
        who = 'SYS' if i % 2 == 0 else 'USR'
        print(f'{who}: {val}')
        
    print(f'label: {example.labe1l}')
    print(f'before_label: {example.before_label}')

# %%
slot_meta
# Out:
# ['관광-경치 좋은',
#  '관광-교육적',
#  '관광-도보 가능',
#  '관광-문화 예술',
#  '관광-역사적',
#  '관광-이름',
#  '관광-종류',
#  '관광-주차 가능',
#  '관광-지역',
#  '숙소-가격대',
#  '숙소-도보 가능',
#  '숙소-수영장 유무',
#  '숙소-스파 유무',
#  '숙소-예약 기간',
#  '숙소-예약 명수',
#  '숙소-예약 요일',
#  '숙소-이름',
#  '숙소-인터넷 가능',
#  '숙소-조식 가능',
#  '숙소-종류',
#  '숙소-주차 가능',
#  '숙소-지역',
#  '숙소-헬스장 유무',
#  '숙소-흡연 가능',
#  '식당-가격대',
#  '식당-도보 가능',
#  '식당-야외석 유무',
#  '식당-예약 명수',
#  '식당-예약 시간',
#  '식당-예약 요일',
#  '식당-이름',
#  '식당-인터넷 가능',
#  '식당-종류',
#  '식당-주류 판매',
#  '식당-주차 가능',
#  '식당-지역',
#  '식당-흡연 가능',
#  '지하철-도착지',
#  '지하철-출발 시간',
#  '지하철-출발지',
#  '택시-도착 시간',
#  '택시-도착지',
#  '택시-종류',
#  '택시-출발 시간',
#  '택시-출발지']

# %% [markdown]
# ## 메모

# %% [markdown]
# 택시 출발지: 숙소에서 택시 출발 다 못 찾음

# %% [markdown]
# ## Normal

# %%
special_values = set(['dontcare'])

use_alternative = True
# 일단은 택시 출발지
alternative_values = {
    '숙소':['숙소-이름'],
    '모텔':['숙소-이름'],
    '호텔':['숙소-이름'],
    '식당':['식당-이름'],
    '관광':['관광-이름'],
    
    '거기':['숙소-이름', '관광-이름','식당-이름'], # 사용해도 될까?
}

# %%
slot_to_check = '식당-예약 요일'
no_space = True

not_found = []
for x in slot2guids[slot_to_check]:
    if x.value in special_values:
        continue
    found = False
    for turn in x.current_turn:
        pat = x.value
        found |= can_find(pat, turn, no_space)
        
    if use_alternative and not found:
        for turn in x.current_turn:
            for k, vv in alternative_values.items():
                pat = k
                if can_find(pat, turn, no_space):
                    for v in vv:
                        if x.before_states.get(v, '') == x.value:
                            found |= True
        
    if not found:
        not_found.append(x)
print(f'{len(slot2guids[slot_to_check])} -> {len(not_found)}')
# Out:
# 4027 -> 301

# %%
# show_example(guid2examples['patient-lab-8392:숙소_관광_택시_14-5'])

# %%
[slot for slot in  slot_meta if '시간' in slot]
# Out:
# ['식당-예약 시간', '지하철-출발 시간', '택시-도착 시간', '택시-출발 시간']

# %% [markdown]
# ## Time

# %%
full_time_formats = [Template('$hour:$mn')]
zero_pad_okay_formats = [Template('$prefix $hour 시 $mn 분'), Template('$prefix $hour 시 $mn')]

zero_min_formats = [Template('$prefix $hour 시')]
half_min_formats = [Template('$prefix $hour 시 반')]

am_formats = ['', '오전', '낮'] # 낮 1시는 언제 , 밤 1시는 언제 오히려 밤 1시가 01이고 낮 1시는 13 이거는 예외처리 필요
pm_formats =['오후', '저녁', '밤']

time2word = '영 한 두 세 네 다섯 여섯 일곱 여덟 아홉 열 열한 열두'.split()

ten2word = '영 일 이 삼 사 오 육 칠 팔 구'.split()

def min2word(mn):
    word = ''
    if mn[0] >= '2':
        word += ten2word[int(mn[0])]
    if mn[0] >= '1':
        word += '십'
    if mn[1] >= '1':
        word += ten2word[int(mn[1])]
    
    if mn == '00':
        word = '영'
    return word

# %%
slot_to_check = '택시-출발 시간'
no_space = True

not_found = []
for x in slot2guids[slot_to_check]:
    if x.value in special_values:
        continue
        
    hour, mn = x.value.split(':')
    zero_pad_list = [(hour, mn)]
    if hour[0] == '0':
        zero_pad_list.append((hour[1], mn))
    if mn[0] == '0' and mn != '00':
        zero_pad_list.append((hour, mn[1]))
    if hour[0] == '0' and mn[0] == '0' and mn != '00':
        zero_pad_list.append((hour[1], mn[1]))

    found = False
    for turn in x.current_turn:
        for pat_format in full_time_formats:
            pat = pat_format.substitute(hour=hour, mn=mn)
            found |= can_find(pat, turn, no_space)
            
            if hour[0] == '0':
                pat = pat_format.substitute(hour=hour[1], mn=mn)
                found |= can_find(pat, turn, no_space)
            
        for pat_format in zero_pad_okay_formats:
            for z_hour, z_mn in zero_pad_list:
                pat = pat_format.substitute(prefix='', hour=z_hour, mn=z_mn)
                found |= can_find(pat, turn, no_space)
                
                if int(z_hour) <= 11:
                    for am in am_formats:
                        pat = pat_format.substitute(prefix=am, hour=z_hour, mn=z_mn)
                        found |= can_find(pat, turn, no_space)
                        
                        pat = pat_format.substitute(prefix=am, hour=time2word[int(hour)%12], mn=z_mn)
                        found |= can_find(pat, turn, no_space)
                        
                        wmn = min2word(mn)
                        pat = pat_format.substitute(prefix=am, hour=z_hour, mn=wmn)
                        found |= can_find(pat, turn, no_space)
                        
                        pat = pat_format.substitute(prefix=am, hour=time2word[int(hour)%12], mn=wmn)
                        found |= can_find(pat, turn, no_space)

                if int(z_hour) >= 13:
                    for pm in pm_formats:
                        pat = pat_format.substitute(prefix=pm, hour=int(z_hour)-12, mn=z_mn)
                        found |= can_find(pat, turn, no_space)
                        
                        wmn = min2word(mn)
                        pat = pat_format.substitute(prefix=pm, hour=z_hour, mn=wmn)
                        found |= can_find(pat, turn, no_space)
                        
                        pat = pat_format.substitute(prefix=pm, hour=time2word[int(hour)%12], mn=wmn)
                        found |= can_find(pat, turn, no_space)
        
        if mn == '00':
            for pat_format in zero_min_formats:
                pat = pat_format.substitute(prefix='',hour=hour, mn=mn)
                found |= can_find(pat, turn, no_space)
                
                if hour[0] == '0':
                    pat = pat_format.substitute(prefix='',hour=hour[1], mn=mn)
                    found |= can_find(pat, turn, no_space)
                
                if int(hour) <= 11:
                    for am in am_formats:
                        pat = pat_format.substitute(prefix=am, hour=hour, mn=mn)
                        found |= can_find(pat, turn, no_space)
                        
                        pat = pat_format.substitute(prefix=am, hour=time2word[int(hour)%12], mn=mn)
                        found |= can_find(pat, turn, no_space)
                if int(hour) >= 13:
                    for pm in pm_formats:
                        pat = pat_format.substitute(prefix=pm, hour=int(hour)-12, mn=mn)
                        found |= can_find(pat, turn, no_space)
                        
                        pat = pat_format.substitute(prefix=pm, hour=time2word[int(hour)%12], mn=mn)
                        found |= can_find(pat, turn, no_space)
            
        if mn == '30':
            for pat_format in half_min_formats:
                pat = pat_format.substitute(prefix='',hour=hour, mn=mn)
                found |= can_find(pat, turn, no_space)
                
                if hour[0] == '0':
                    pat = pat_format.substitute(prefix='',hour=hour[1], mn=mn)
                    found |= can_find(pat, turn, no_space)
                    
                pat = pat_format.substitute(prefix='',hour=time2word[(int(hour)-1)%12+1], mn=mn)
                found |= can_find(pat, turn, no_space)
                
                if int(hour) <= 11:
                    for am in am_formats:
                        pat = pat_format.substitute(prefix=am, hour=z_hour, mn=z_mn)
                        found |= can_find(pat, turn, no_space)
                if int(hour) >= 13:
                    for pm in pm_formats:
                        pat = pat_format.substitute(prefix=pm, hour=int(z_hour)-12, mn=z_mn)
                        found |= can_find(pat, turn, no_space)
        
    if not found:
        not_found.append(x)
print(f'{len(slot2guids[slot_to_check])} -> {len(not_found)}')
# Out:
# 2935 -> 21

# %% [markdown]
# # Filters

# %% [markdown]
# ## Time Filter

# %%
def filter_no_str(matches):
    if len(matches) == 0:
        return matches
    if not isinstance(matches[0], tuple):
        return [matches]
    return [[x.strip() for x in match if len(x.strip()) > 0] for match in matches]

# %%
time2word = '영 한 두 세 네 다섯 여섯 일곱 여덟 아홉 열 열한 열두'.split()
word2index = {x:idx for idx, x in enumerate(time2word)}

time_zone = [
    '오후',
    '오전',
    '저녁',
    '낮',
    '밤',
    '새벽',
]
time_zone_pat = '|'.join(time_zone)

def solve_time(time_zone_info, hour):
    time_zone_info = time_zone_info.strip()
    if time_zone_info == '오후':
        if hour < 12:
            hour += 12
    elif time_zone_info == '오전':
        pass
    elif time_zone_info == '저녁':
        if hour < 12:
            hour += 12
    elif time_zone_info == '낮':
        if hour < 5:
            hour += 12

    elif time_zone_info == '밤':
        if hour < 12:
            hour += 12
    elif time_zone_info == '새벽':
        pass
    else:
        print('not found: ',time_zone_info)    
        raise NotImplementedError()
    
    return hour

    
ten2word = '영 일 이 삼 사 오 육 칠 팔 구'.split()
ten2word_dict = {x:idx for idx, x in enumerate(ten2word)}

prefix_ten = '|'.join('영 일 이 삼 사 오 육'.split())


def word2min(word):
    word = word.strip()
    
    size = 0
    stack = []
    for w in word:
        if w == '십':
            count = 10
        else:
            count = ten2word_dict[w]
        if size == 0 or stack[-1] >= count:
            stack.append(count)
            size += 1
        else:
            stack[-1] *= count
            
    return sum(stack)
        
def min2word(mn):
    word = ''
    if mn[0] >= '2':
        word += ten2word[int(mn[0])]
    if mn[0] >= '1':
        word += '십'
    if mn[1] >= '1':
        word += ten2word[int(mn[1])]
    
    if mn == '00':
        word = '영'
    return word
    

patterns = [
    r'(\d\d?)\s*:\s*(\d\d)',          # 09:23, 2:23
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*(\d\d?)\s*분?',   # 9시 23분, 09시     2분, 4시4
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*(\d\d?)\s*분?',
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*((?:(?:(?:{prefix_ten})?십)(?:{ten2word})|(?:(?:{prefix_ten})?십)|(?:{ten2word})))\s*분',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*((?:(?:(?:{prefix_ten})?십)(?:{ten2word})|(?:(?:{prefix_ten})?십)|(?:{ten2word})))\s*분'
]

half_patterns = [
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*(?:반|30분?)',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*(?:반|30\s*분?)', 
]

hour_only_patterns = [
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시',
]

pat = '|'.join(patterns)
half_pat = '|'.join(half_patterns)
hour_only_pat = '|'.join(hour_only_patterns)

# %%
slot_to_check = '식당-예약 시간'
no_space = True


sys_turn = '안녕하세요. 서울 송파구에 위치한 랍스터를 판매하는 누가또가재는 어떠세요?'
usr_turn = '안그래도 랍스터를 먹은지 진짜 오래됐는데.. 추천해주신김에 한번 방문해봐야겠어요. 금요일에 20시20분으로 2명 예약 가능할까요?'
slots_to_check = ['식당-예약 시간-06:12']

# slots_to_check = time slots only
def filter_time(sys_turn, usr_turn, slots_to_check, no_space=True):
    turns = [sys_turn, usr_turn]
    not_found = []
    for slot_value in slots_to_check:
        domain, value = split_slot(slot_value, True)
        if value in special_values:
            continue
            
            
        pat = value
        found = False
        for turn in turns:
            found |= can_find(pat, turn, no_space)

        if not found:
            not_found.append(slot_value)
    return len(not_found) == 0, not_found
        
    
filter_time(sys_turn, usr_turn, slots_to_check)


def filter_by_time(turn, value):
    if value in special_values:
        return False
    
    # filter by h:m
    matches = re.findall(pat, turn, overlapped=False)
    matches = filter_no_str(matches)
    for match in matches:
        if len(match) < 2:
            continue

        if len(match) == 3:
            if match[1] in word2index:
                match[1] = word2index[match[1]]
            match[0] = solve_time(match[0], int(match[1]))
            match[1] = match[2]
        else:
            if match[0] in word2index:
                match[0] = word2index[match[0]]

        if not ('0' <= match[1].strip()[0] <= '9'):
            match[1] = word2min(match[1])

        if f'{match[0]:0>2}:{match[1]:0>2}' == value:
            return True

    # filter by h:30
    half_matches = re.findall(half_pat, turn, overlapped=False)
    half_matches = filter_no_str(half_matches)
    for match in half_matches:
        if len(match) == 2:
            if match[1] in word2index:
                match[1] = word2index[match[1]]
            match[0] = solve_time(match[0], int(match[1]))
        else:
            if match[0] in word2index:
                match[0] = word2index[match[0]]

        if f'{match[0]:0>2}:30' == value:
            return True

    # filter by h:00
    hour_only_matches = re.findall(hour_only_pat, turn, overlapped=False)
    hour_only_matches = filter_no_str(hour_only_matches)
    for match in hour_only_matches:
        if len(match) == 2:
            if match[1] in word2index:
                match[1] = word2index[match[1]]
            match[0] = solve_time(match[0], int(match[1]))
        else:
            if match[0] in word2index:
                match[0] = word2index[match[0]]

        if f'{match[0]:0>2}:00' == value:
            return True
        
    return False

# %% [markdown]
# ## default filter

# %%
special_values = set(['dontcare']) # 이거는 해결 못함

no_space = True

sys_turn = '안녕하세요. 서울 송파구에 위치한 랍스터를 판매하는 누가또가재는 어떠세요?'
usr_turn = '안그래도 랍스터를 먹은지 진짜 오래됐는데.. 추천해주신김에 한번 방문해봐야겠어요. 금요일에 20시20분으로 2명 예약 가능할까요?'
slots_to_check = ['식당-예약 시간-20:20', '식당-예약 요일-금요일', '식당-이름-누가또가재']

time_slots = set(['식당-예약 시간', '지하철-출발 시간', '택시-도착 시간', '택시-출발 시간'])
def filter_normal(sys_turn, usr_turn, slots_to_check, no_space=True):
    turns = [sys_turn, usr_turn]
    not_found = []
    for slot_value in slots_to_check:
        domain, value = split_slot(slot_value, True)
        if value in special_values:
            continue
            
        found = False
        if domain in time_slots:
            for turn in turns:
                found |= filter_by_time(turn, value)
        else:
            pat = value
            for turn in turns:
                found |= can_find(pat, turn, no_space)

        if not found:
            not_found.append(slot_value)
    return len(not_found) == 0, not_found
        
    
filter_normal(sys_turn, usr_turn, slots_to_check)
# Out:
# (True, [])

# %% [markdown]
# ## Archive

# %%
def filter_no_str(matches):
    if len(matches) == 0:
        return matches
    if not isinstance(matches[0], tuple):
        return [matches]
    return [[x.strip() for x in match if len(x.strip()) > 0] for match in matches]

# %%
time2word = '영 한 두 세 네 다섯 여섯 일곱 여덟 아홉 열 열한 열두'.split()
word2index = {x:idx for idx, x in enumerate(time2word)}

time_zone = [
    '오후',
    '오전',
    '저녁',
    '낮',
    '밤',
    '새벽',
]
time_zone_pat = '|'.join(time_zone)

def solve_time(time_zone_info, hour):
    time_zone_info = time_zone_info.strip()
    if time_zone_info == '오후':
        if hour < 12:
            hour += 12
    elif time_zone_info == '오전':
        pass
    elif time_zone_info == '저녁':
        if hour < 12:
            hour += 12
    elif time_zone_info == '낮':
        if hour < 5:
            hour += 12

    elif time_zone_info == '밤':
        if hour < 12:
            hour += 12
    elif time_zone_info == '새벽':
        pass
    else:
        print('not found: ',time_zone_info)    
        raise NotImplementedError()
    
    return hour

    
ten2word = '영 일 이 삼 사 오 육 칠 팔 구'.split()
ten2word_dict = {x:idx for idx, x in enumerate(ten2word)}

prefix_ten = '|'.join('영 일 이 삼 사 오 육'.split())


def word2min(word):
    word = word.strip()
    
    size = 0
    stack = []
    for w in word:
        if w == '십':
            count = 10
        else:
            count = ten2word_dict[w]
        if size == 0 or stack[-1] >= count:
            stack.append(count)
            size += 1
        else:
            stack[-1] *= count
            
    return sum(stack)
        
def min2word(mn):
    word = ''
    if mn[0] >= '2':
        word += ten2word[int(mn[0])]
    if mn[0] >= '1':
        word += '십'
    if mn[1] >= '1':
        word += ten2word[int(mn[1])]
    
    if mn == '00':
        word = '영'
    return word
    

patterns = [
    r'(\d\d?)\s*:\s*(\d\d)',          # 09:23, 2:23
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*(\d\d?)\s*분?',   # 9시 23분, 09시     2분, 4시4
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*(\d\d?)\s*분?',
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*((?:(?:(?:{prefix_ten})?십)(?:{ten2word})|(?:(?:{prefix_ten})?십)|(?:{ten2word})))\s*분',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*((?:(?:(?:{prefix_ten})?십)(?:{ten2word})|(?:(?:{prefix_ten})?십)|(?:{ten2word})))\s*분'
]

half_patterns = [
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시\s*(?:반|30분?)',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시\s*(?:반|30\s*분?)', 
]

hour_only_patterns = [
    fr'((?:{time_zone_pat})\s*)?(\d\d?)\s*시',
    fr'((?:{time_zone_pat})\s*)?({"|".join(time2word)})\s*시',
]

pat = '|'.join(patterns)
half_pat = '|'.join(half_patterns)
hour_only_pat = '|'.join(hour_only_patterns)

# %%
slot_to_check = '식당-예약 시간'
no_space = True

old_found = not_found
not_found = []
for x in slot2guids[slot_to_check]:
# for x in [use_found[3]]:
# for x in old_found:
    if x.value in special_values:
        continue
        
    found = False
    for turn in x.current_turn:
        matches = re.findall(pat, turn, overlapped=False)

        matches = filter_no_str(matches)
        for match in matches:
            if len(match) < 2:
                continue
                
            if len(match) == 3:
                if match[1] in word2index:
                    match[1] = word2index[match[1]]
                match[0] = solve_time(match[0], int(match[1]))
                match[1] = match[2]
            else:
                if match[0] in word2index:
                    match[0] = word2index[match[0]]
                    
            if not ('0' <= match[1].strip()[0] <= '9'):
                match[1] = word2min(match[1])
                    
            found |= (f'{match[0]:0>2}:{match[1]:0>2}' == x.value)
        
        half_matches = re.findall(half_pat, turn, overlapped=False)
        half_matches = filter_no_str(half_matches)
        for match in half_matches:
            if len(match) == 2:
                if match[1] in word2index:
                    match[1] = word2index[match[1]]
                match[0] = solve_time(match[0], int(match[1]))
            else:
                if match[0] in word2index:
                    match[0] = word2index[match[0]]

            found |= (f'{match[0]:0>2}:30' == x.value)
            
        hour_only_matches = re.findall(hour_only_pat, turn, overlapped=False)
        hour_only_matches = filter_no_str(hour_only_matches)
        for match in hour_only_matches:
            if len(match) == 2:
                if match[1] in word2index:
                    match[1] = word2index[match[1]]
                match[0] = solve_time(match[0], int(match[1]))
            else:
                if match[0] in word2index:
                    match[0] = word2index[match[0]]

            found |= (f'{match[0]:0>2}:00' == x.value)

    if not found:
        not_found.append(x)
        
print(f'{len(slot2guids[slot_to_check])} -> {len(not_found)}')
# Out:
# [
#  autumn-mountain-9993:식당_관광_지하철_14-1
#  VAL: 03:30
#  SYS: 안녕하세요? 서울 광희동에 위치한 평점 4점의 어차피자라는 곳은 어떠신가요?
#  USR: 피자집인거죠? 괜찮네요. 저 여기로 금요일 3시에 4명으로 예약 부탁드립니다.
#  before: {'식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '양식당'},
#
#  dark-resonance-0485:식당_택시_8-2
#  VAL: 15:00
#  SYS: 네 그러면 외계인의맛집과 만칠천무한리필을 추천 드리는데 어디로 예약 도와드릴까요?
#  USR: 무한리필은 맛없으니깐 외계인의맛집으로 할께요. 예약 하고 식당에 10시까지 도착하는 택시도 같이 불러주세요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 중앙', '식당-종류': '한식당', '식당-흡연 가능': 'yes'},
#
#  tight-sky-0988:숙소_식당_택시_10-4
#  VAL: 23:20
#  SYS: 혹시 서울 강서구에 위치한 스위소보루라는 곳은 어떠세요?
#  USR: 음. 방금 사진을 찾아봤는데 굉장히 먹음직스럽네요. 화요일 23시30분에 여기로 4명 예약해주세요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': 'dontcare', '숙소-지역': '서울 중앙', '숙소-예약 요일': '일요일', '숙소-예약 명수': '4', '숙소-예약 기간': '3', '숙소-이름': '동키 게스트 하우스', '식당-가격대': '저렴', '식당-지역': 'dontcare', '식당-종류': '베이커리'},
#
#  falling-king-5536:식당_숙소_택시_15-3
#  VAL: 14:30
#  SYS: 슈크림 빵입니다.
#  USR: 그럼 화요일 2시 반에 한 명으로 예약해 주세요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 동쪽', '식당-종류': '베이커리'},
#
#  withered-queen-5280:숙소_식당_1-8
#  VAL: 14:00
#  SYS: 네. 시간은 몇시로 해드릴까요?
#  USR: 아 시간은 2시요. 예약 하고 주소도 말씀해주시구요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': 'dontcare', '숙소-지역': 'dontcare', '숙소-주차 가능': 'yes', '숙소-예약 요일': '일요일', '숙소-예약 명수': '4', '숙소-예약 기간': '2', '숙소-이름': '시그니처 서울', '식당-가격대': 'dontcare', '식당-지역': '서울 동쪽', '식당-종류': '주점', '식당-예약 요일': '일요일', '식당-예약 명수': '4', '식당-이름': '주점부리'},
#
#  little-shadow-4911:숙소_식당_11-6
#  VAL: 08:20
#  SYS: 조건에 맞는 곳으로 평점 4.5점의 친구를 만나느라 샵샵샵이 있습니다. 예약해드릴까요?
#  USR: 흡연은 가능하죠?
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': '호텔', '숙소-지역': '서울 중앙', '숙소-인터넷 가능': 'yes', '숙소-스파 유무': 'yes', '숙소-예약 요일': '일요일', '숙소-예약 명수': '4', '숙소-예약 기간': '3', '숙소-이름': '가야 호텔', '식당-가격대': '적당', '식당-지역': '서울 중앙', '식당-종류': '일식당'},
#
#  tight-meadow-5155:식당_27-4
#  VAL: 16:45
#  SYS: 알겠습니다. 예약을 원하시는 날짜와 시간, 인원 말씀해주시겠어요?
#  USR: 월요일 4시 45분으로 2명입니다.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 서쪽', '식당-종류': '일식당', '식당-야외석 유무': 'yes', '식당-이름': '사시사철미식가'},
#
#  proud-cherry-7862:식당_관광_택시_13-1
#  VAL: 02:59
#  SYS: 안녕하세요? 원하시는 식당의 종류는 어떤 것으로 찾아봐 드릴까요?
#  USR: 종류는 상관 없고, 토요일 2;59에 2명이 예약 가능한 곳으로 부탁 드립니다.
#  before: {'식당-가격대': '적당', '식당-지역': '서울 중앙'},
#
#  yellow-hat-9102:관광_식당_택시_13-4
#  VAL: 12:46
#  SYS: 네, 도보 가능한 양식당 내맘속의나폴리입니다. 경복궁역에서 도보 7분 거리로, 대표 메뉴는 파스타입니다.
#  USR: 거기로 할게요. 금요일 12시 4분에 6명이고요, 식당에서 강남역으로 가는 택시도 잡아주세요.
#  before: {'관광-종류': '공원', '관광-지역': 'dontcare', '관광-경치 좋은': 'yes', '관광-이름': '하늘공원', '식당-가격대': '적당', '식당-지역': '서울 중앙', '식당-종류': '양식당', '식당-도보 가능': 'yes'},
#
#  bold-mode-4145:관광_식당_숙소_11-3
#  VAL: 08:10
#  SYS: 네. 알겠습니다. 식당 지역은 어디로 봐드릴까요?
#  USR: 지역은 상관하지 마시고 봐주셔도 됩니다. 화요일에 18시10분 예약이 가능한 곳으로 좀 추려서 봐주세요.
#  before: {'관광-종류': 'dontcare', '관광-지역': 'dontcare', '관광-주차 가능': 'yes', '관광-이름': '롯데월드타워&몰', '식당-가격대': '비싼', '식당-종류': '양식당', '식당-야외석 유무': 'yes'},
#
#  cool-shape-2579:식당_숙소_관광_20-2
#  VAL: 15:20
#  SYS: 그러시면 루이필라프2세라는 양식당을 가보시는 건 어떠실까요? 가격대도 적당하고 평점도 4.3으로 좋은 편인데요.
#  USR: 네네, 거기로 해주세요. 토요일 3시 20분으로 아까 말씀드린 것처럼 8명으로 해주시면 돼요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 서쪽', '식당-종류': 'dontcare', '식당-예약 명수': '8'},
#
#  purple-cell-6101:식당_관광_12-1
#  VAL: 14:30
#  SYS: 안녕하세요. 말씀하신 곳은 서울 동쪽에 위치한 분식집으로, 인당 만원 정도로 저렴한 곳 입니다.
#  USR: 그렇군요. 거기서 이따 2시 30분쯤에 점심먹으러 가고싶은데 4명 예약 가능한가요?
#  before: {'식당-이름': '분식회개'},
#
#  cool-wood-2933:숙소_식당_13-5
#  VAL: 15:50
#  SYS: 두 곳 가능하신데요. 가격대가 조금 더 저렴한 편인 꿔=바로우라는 곳은 어떠실까요? 인당 만오천원정도 됩니다.
#  USR: 아 네네 괜찮네요. 거기 예약 좀 해주세요. 수요일 15시 15분에 2명이요.
#  before: {'숙소-가격대': '저렴', '숙소-종류': '호스텔', '숙소-지역': '서울 동쪽', '숙소-예약 요일': '일요일', '숙소-예약 명수': '2', '숙소-예약 기간': '5', '숙소-이름': '나이팅게일 호스텔', '식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '중식당'},
#
#  nameless-art-3725:식당_3-3
#  VAL: 03:20
#  SYS: 아 말씀주신 시간대는 예약만료시네요.
#  USR: 아 그래요? 그럼 3시... 20분은요?
#  before: {'식당-가격대': '비싼', '식당-지역': '서울 동쪽', '식당-종류': '양식당', '식당-예약 요일': '화요일', '식당-예약 시간': '18:30', '식당-예약 명수': '4', '식당-이름': '누가또가재'},
#
#  square-bush-9349:숙소_식당_1-9
#  VAL: 17:00
#  SYS: 서울 북쪽에 두 곳이 나오는데요, 떡볶이가 유명한 한시간삼십분식과 라면이 유명한 내가만약석박이라면 두 군데가 나오네요. 어디로 예약해드릴까요?
#  USR: 아무래도 분식이면 떡볶이죠. 그 한시간삼십분식으로 해주세요. 그 일요일날 5시에 두 사람으로요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': 'dontcare', '숙소-지역': 'dontcare', '숙소-주차 가능': 'yes', '숙소-예약 요일': '일요일', '숙소-예약 명수': '2', '숙소-예약 기간': '2', '숙소-이름': '프린스 호텔 서울', '식당-가격대': 'dontcare', '식당-지역': '서울 중앙', '식당-종류': '분식집'},
#
#  floral-night-2505:숙소_식당_관광_14-6
#  VAL: 14:30
#  SYS: 그러시면 두유노코리안으로 예약해보시는 건 어떨까요? 한식당 중에서 평점이 4.5로 높기도 하고 가격도 2만원 대로 적당한 곳인데요.
#  USR: 네, 거기 괜찮네요. 화요일 2시 30분에 5명으로 예약 좀 부탁드릴게요.
#  before: {'숙소-가격대': '비싼', '숙소-종류': '에어비엔비', '숙소-지역': '서울 동쪽', '숙소-예약 요일': '일요일', '숙소-예약 명수': '3', '숙소-예약 기간': '3', '숙소-이름': '시그니처 서울', '식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '한식당'},
#
#  super-art-0530:식당_31-3
#  VAL: 17:30
#  SYS: 일식당은 네 곳이 있다고 나오네요. 서대문구에 믿고맡기는초밥과 오동통규동동 그리고 중구에는 회오리라멘과 친구를 만나느라 샵샵샵 이렇게 있는데 어디로 예약하시겠어요?
#  USR: 초밥집이 좋을것 같네요. 믿고맡기는초밥에 월요일 5시30분에 두 명 예약해주세요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 중앙', '식당-종류': '일식당'},
#
#  sweet-dream-9563:관광_식당_숙소_13-3
#  VAL: 16:10
#  SYS: 꿔=바로우 어떠세요? 평점은 3.5 입니다.
#  USR: 네 예약해주세요. 일요일에 16시 3명 해주세요. 그리고 역에서부터 걸어가는 시간도 알아봐주시겠어요?
#  before: {'관광-이름': '봉은사', '식당-가격대': 'dontcare', '식당-지역': '서울 남쪽', '식당-종류': '중식당', '식당-주류 판매': 'yes'},
#
#  shiny-flower-4503:식당_관광_택시_15-1
#  VAL: 15:00
#  SYS: 그러십니까? 잠시만요. 사시사철미식가 평점은 3.5점 정도 되구요, 가격대는 5만원대로 나오시네요. 예약 도와드릴까요?
#  USR: 네네. 예약해주세요. 월요일 3시 2명으로 해주시면 됩니다.
#  before: {'식당-이름': '사시사철미식가'},
#
#  muddy-cherry-8523:식당_16-2
#  VAL: 16:45
#  SYS: 아 죄송하지만, 해당 시간은 예약 힘드시네요. 4시대는 가능하신데 어떡하시겠어요?
#  USR: 아 그래요? 그럼 4시 45분으로 예약할게요.
#  before: {'식당-가격대': '적당', '식당-지역': '서울 중앙', '식당-종류': '베이커리', '식당-예약 요일': '일요일', '식당-예약 시간': '05:45', '식당-예약 명수': '2', '식당-이름': '한가한과'},
#
#  raspy-river-9072:식당_11-4
#  VAL: 09:00
#  SYS: 인원은 몇 분이세요?
#  USR: 저 혼자입니다.
#  before: {'식당-가격대': '비싼', '식당-지역': '서울 동쪽', '식당-종류': 'dontcare', '식당-주차 가능': 'yes', '식당-인터넷 가능': 'yes', '식당-예약 요일': '금요일', '식당-이름': '누가또가재'},
#
#  tight-glade-5986:관광_숙소_식당_11-9
#  VAL: 08:00
#  SYS: 중앙에는 외계인의맛집이랑 한정식 맛집이 있습니다. 평점도 4.3점이구요.
#  USR: 아 그럼 거기로 예약할게요. 식당도 토요일에 3명으로 예약해 주시고 인원은 8명이에요.
#  before: {'관광-종류': '랜드마크', '관광-지역': 'dontcare', '관광-역사적': 'yes', '관광-이름': '세종대왕 동상', '숙소-가격대': 'dontcare', '숙소-종류': '게스트 하우스', '숙소-지역': '서울 북쪽', '숙소-예약 요일': '토요일', '숙소-예약 명수': '3', '숙소-예약 기간': '4', '숙소-이름': '호두나무집', '식당-가격대': '비싼', '식당-지역': '서울 중앙', '식당-종류': '한식당', '식당-야외석 유무': 'yes'},
#
#  aged-lake-2675:식당_2-3
#  VAL: 06:45
#  SYS: 잠시만요. 서초구에 위치한 꿔=바로우라는 식당이 있습니다만 요청하신 시간에는 이미 예약이 완료된 상황입니다.
#  USR: 저 그러면 그 뒷 시간으로 한번 봐주시겠어요?
#  before: {'식당-가격대': '적당', '식당-지역': '서울 남쪽', '식당-종류': '중식당', '식당-예약 요일': '목요일', '식당-예약 시간': '05:20', '식당-예약 명수': '2', '식당-이름': '꿔=바로우'},
#
#  red-glade-4950:식당_택시_10-2
#  VAL: 13:00
#  SYS: 야외석이 없는곳으로는 두부두부두부라는 순두부찌개 전문점이 있습니다.
#  USR: 거기로 그럼 월요일 1시로 7명 예약해 주세요.
#  before: {'식당-가격대': '저렴', '식당-지역': '서울 동쪽', '식당-종류': '한식당', '식당-야외석 유무': 'no'},
#
#  polished-sun-6484:식당_숙소_지하철_11-2
#  VAL: 03:50
#  SYS: 네. 알겠습니다. 총 4곳이 확인되는데요. 그 중 서울 종로구에 있는 뽀식이네 감자탕은 어떠세요?
#  USR: 아 메뉴 너무너무 괜찮네요. 3시40분으로 5명 좀 예약해주세요. 혹시 가까운 지하철역은 어디인가요?
#  before: {'식당-가격대': '비싼', '식당-지역': '서울 중앙', '식당-종류': 'dontcare', '식당-주류 판매': 'yes', '식당-예약 요일': '일요일'},
#
#  autumn-mountain-4452:관광_식당_지하철_14-3
#  VAL: 03:54
#  SYS: 치킨키친과 가까운 지하철역은 도보 7분거리에 있는 사당역입니다.
#  USR: 그럼 그 곳에 금요일 03시45분에 3명 예약해주세요.
#  before: {'관광-종류': 'dontcare', '관광-지역': 'dontcare', '관광-경치 좋은': 'yes', '관광-이름': '여의도 한강공원', '식당-이름': '치킨키친'},
#
#  blue-sea-5601:식당_10-1
#  VAL: 15:00
#  SYS: 네 안녕하세요 검색결과 고속터미널역과 가까운 사차원주머니라는 곳이 있습니다. 예약하시겠습니까?
#  USR: 네 예약해주세요 저희 총 9명이고 일요일 3시로요
#  before: {'식당-가격대': '적당', '식당-지역': '서울 남쪽', '식당-종류': '베이커리'},
#
#  rough-dream-3386:숙소_관광_식당_12-5
#  VAL: 14:20
#  SYS: 성동구에 위치한 샌드위치 전문점인 밀수업자라는 곳은 어떠신가요?
#  USR: 음. 괜찮네요. 여기로 수요일 13시20분에 2명으로 예약 좀 부탁드려요.
#  before: {'관광-이름': '동대문 (흥인지문)', '숙소-가격대': '적당', '숙소-종류': '호텔', '숙소-지역': '서울 동쪽', '숙소-예약 요일': '수요일', '숙소-예약 명수': '4', '숙소-예약 기간': '1', '숙소-이름': '행복 호텔', '식당-가격대': '저렴', '식당-지역': '서울 북쪽', '식당-종류': '베이커리'},
#
#  blue-sun-4544:식당_8-2
#  VAL: 15:00
#  SYS: 네. 총 네곳이 검색되시는데 평점이 높고 왕십리역과 가까운 치키웨이라는 곳은 어떠세요? 치킨집입니다.
#  USR: 아 치킨이요? 네 거기로 예약할게요. 수요일 3시에 1명이요.
#  before: {'식당-가격대': '적당', '식당-지역': '서울 북쪽', '식당-종류': 'dontcare'},
#
#  summer-feather-1654:식당_12-3
#  VAL: 20:30
#  SYS: 죄송하지만 해당 시간은 예약 어렵습니다. 다른 시간대는 다 가능한 걸로 나오시는데 변경하시겠어요?
#  USR: 그럼 8시반으로 변경해줘요
#  before: {'식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '한식당', '식당-야외석 유무': 'yes', '식당-예약 요일': '금요일', '식당-예약 시간': '23:15', '식당-예약 명수': '1', '식당-이름': '식스타임즈'},
#
#  hidden-rice-4945:식당_13-2
#  VAL: 17:30
#  SYS: 네. 한 곳 가능하십니다. 사당역과 가깝고 마늘치킨이 유명한 치킨치킨이라는 곳입니다. 예약하시겠어요?
#  USR: 마늘치킨요? 네 거기할게요. 월요일 5시 30분에 일곱명 예약해주세요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 남쪽', '식당-종류': '치킨집', '식당-주류 판매': 'yes', '식당-야외석 유무': 'yes'},
#
#  misty-fire-9968:관광_식당_숙소_14-3
#  VAL: 12:06
#  SYS: 한 곳 확인되네요. 홍대입구역의 술판오브디스코입니다. 예약 필요하세요?
#  USR: 네 월요일 12시 5분, 3명으로 해주심 되구요, 혹시 주차랑 인터넷 가능한가요?
#  before: {'관광-종류': '박물관', '관광-지역': '서울 남쪽', '관광-교육적': 'yes', '관광-이름': '국립국악원', '식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '주점'},
#
#  plain-dust-3568:관광_식당_택시_13-2
#  VAL: 15:46
#  SYS: 네, 공원 주소는 서울 영등포구 19471입니다. 식당은 건대입구역의 떡튀순으로 유명한 분식회개 확인되는데요, 예약 필요하세요?
#  USR: 네 할게요. 금요일 15시 4분에 4명이구요, 건대입구역에서 얼마나 걸어야 되나요?
#  before: {'관광-종류': '공원', '관광-지역': 'dontcare', '관광-경치 좋은': 'yes', '관광-이름': '여의도 공원', '식당-가격대': '저렴', '식당-지역': '서울 동쪽', '식당-종류': '분식집', '식당-도보 가능': 'yes'},
#
#  red-cake-8933:숙소_식당_12-5
#  VAL: 01:00
#  SYS: 서울 강서구에 위치한 스윗소보루는 어떠신가요? 평점 4.5의 베이커리입니다.
#  USR: 좋습니다. 1인으로 바로 여기 예약 좀 해주세요. 대표 메뉴가 어떻게 되죠?
#  before: {'숙소-가격대': '적당', '숙소-종류': 'dontcare', '숙소-지역': '서울 서쪽', '숙소-예약 요일': '일요일', '숙소-예약 명수': '1', '숙소-예약 기간': '3', '숙소-이름': '아카펠라', '식당-가격대': 'dontcare', '식당-지역': '서울 서쪽', '식당-종류': '베이커리', '식당-예약 요일': '일요일', '식당-예약 명수': '1'},
#
#  tight-breeze-9665:식당_택시_8-1
#  VAL: 02:00
#  SYS: 네 명동역에서 도보 3분거리에 위치한 평점 4.5점의 일식당 친구를 만나느라 샵샵샵을 찾았습니다.
#  USR: 아 그럼 그 식당으로 목요일 20시에 2명 예약해주세요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 중앙', '식당-종류': '일식당', '식당-흡연 가능': 'yes'},
#
#  mute-scene-8916:관광_식당_숙소_11-6
#  VAL: 13:00
#  SYS: 서초구에 이기자카야와 마포구에 술판오브디스코가 야외석이 있는데 어디가 괜찮으세요? 이기자카야는 스키야키가 대표 메뉴이며, 술판오브디스코는 해물누룽지탕이 대표 메뉴입니다.
#  USR: 스키야키가 더 끌리네요. 이기자카야로 일요일 13에 예약해주시겠어요? 2명이 갈거예요.
#  before: {'관광-종류': 'dontcare', '관광-지역': 'dontcare', '관광-주차 가능': 'yes', '관광-이름': '남산 케이블카', '식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '주점', '식당-야외석 유무': 'yes'},
#
#  patient-snowflake-5480:숙소_식당_택시_10-6
#  VAL: 16:09
#  SYS: 그러시면 스윗소보루라는 베이커리를 가보시는 걸 추천해드리고 싶은데요, 평도 4.5점으로 매우 높은 편이구요, 지하철 역에서도 그리 멀지 않아서 걸어서 찾아가시기에도 편한 곳이거든요.
#  USR: 그래요? 그러면 거기 예약도 될까요? 토요일 한 4시 9분 정도에 4명이서 가고 싶은데요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': '호텔', '숙소-지역': 'dontcare', '숙소-예약 요일': '일요일', '숙소-예약 명수': '4', '숙소-예약 기간': '3', '숙소-이름': '힐링 호텔', '식당-가격대': '저렴', '식당-지역': 'dontcare', '식당-종류': '베이커리'},
#
#  dark-grass-3171:식당_숙소_관광_19-1
#  VAL: 17:40
#  SYS: 네, 가능한지 한번 봐드릴게요. 언제로 예약해드리면 될까요?
#  USR: 월요일 5시 40분으로요! 그 2명이서 갈 거예요.
#  before: {'식당-이름': '스윗소보루'},
#
#  morning-star-0345:식당_관광_숙소_9-2
#  VAL: 13:20
#  SYS: 그러시면 한시간삼십분식으로 가보시는 건 어떠실까요? 떡볶이가 아주 유명한 맛집으로 검색되는데요.
#  USR: 네, 그러면 월요일에 6명으로 예약 되는지 봐주실래요? 되면 1시 20분으로 예약해주시구요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 북쪽', '식당-종류': '분식집'},
#
#  dark-cell-7468:숙소_식당_10-1
#  VAL: 05:50
#  SYS: 안녕하세요~ 무엇을 도와드릴까요?
#  USR: 프로젝트 팀과 식사할 곳을 찾고 있는데요
#  before: {},
#
#  white-base-8556:숙소_식당_11-6
#  VAL: 13:20
#  SYS: 알겠습니다. 광진구에 주점부리라는 곳이 있는데 이 곳이 괜찮으실것 같네요. 수제 맥주 판매하는 곳인데 평점 4.5점으로 평도 좋습니다.
#  USR: 괜찮네요. 거기 화요일 13시 30분에 갈건데 예약하고 전화번호랑 예약 번호 알려주세요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': '호텔', '숙소-지역': '서울 동쪽', '숙소-인터넷 가능': 'yes', '숙소-스파 유무': 'yes', '숙소-예약 요일': '수요일', '숙소-예약 명수': '5', '숙소-예약 기간': '3', '숙소-이름': '행복 호텔', '식당-가격대': 'dontcare', '식당-지역': '서울 동쪽', '식당-종류': '주점', '식당-흡연 가능': 'yes', '식당-예약 명수': '1'},
#
#  autumn-grass-0110:숙소_식당_관광_11-6
#  VAL: 17:40
#  SYS: 아 광희동에 위치한 닭발먹고오리발내민다가 있습니다. 이곳으로 예약할까요?
#  USR: 네 친구랑 같이갈거라서 금요일날 9명이요. 시간은 17:45쯤 될것같아요.
#  before: {'숙소-가격대': '비싼', '숙소-종류': 'dontcare', '숙소-지역': 'dontcare', '숙소-헬스장 유무': 'yes', '숙소-스파 유무': 'yes', '숙소-예약 요일': '일요일', '숙소-예약 명수': '1', '숙소-예약 기간': '2', '숙소-이름': '가야 호텔', '식당-가격대': 'dontcare', '식당-지역': '서울 북쪽', '식당-종류': '한식당'},
#
#  still-voice-2050:식당_택시_9-0
#  VAL: 23:00
#  SYS:
#  USR: 금요일에 까스까스까스 식당 예약 좀 할건데요. 22시에 3명으로 예약될까요?
#  before: {},
#
#  round-tree-5195:숙소_식당_10-1
#  VAL: 23:53
#  SYS: 안녕하세요. 원하시는 곳이 검색되지 않는데, 혹시 지역을 서울 남쪽으로 추천해드려도 될까요?
#  USR: 좋아요. 월요일 23:52에 6명갈거에요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': 'dontcare', '식당-종류': 'dontcare'},
#
#  sweet-butterfly-5992:식당_택시_10-2
#  VAL: 02:00
#  SYS: 가지가지차이나는 어떠신가요? 신도림역에서 7분거리입니다.
#  USR: 괜찮네요 목요일에 22:00 6명 예약해주시고 대표 메뉴랑 예약번호 알려주세요
#  before: {'식당-가격대': '적당', '식당-지역': '서울 서쪽', '식당-종류': '중식당', '식당-야외석 유무': 'no'},
#
#  shiny-block-1632:식당_27-2
#  VAL: 14:30
#  SYS: 네, 해당 조건으로 한 곳 뜨시네요. 동대문역에서 가깝고 인터넷 사용 가능한 어차피자입니다. 예약해드릴까요/
#  USR: 어차피자요? 들어본거 같은데.... 네 예약해주세요. 금요일 2시반 두명이요.
#  before: {'식당-가격대': 'dontcare', '식당-지역': '서울 북쪽', '식당-종류': '양식당', '식당-주류 판매': 'yes', '식당-야외석 유무': 'yes'},
#
#  raspy-thunder-3330:식당_택시_9-0
#  VAL: 04:30
#  SYS:
#  USR: 술판오브디스코라는 식당에 일요일 04:00 3명 예약해주세요
#  before: {},
#
#  jolly-glitter-7119:관광_식당_7-5
#  VAL: 12:00
#  SYS: 두 곳 가능합니다. 건대입구역의 분식회개라는 곳인데요. 인터넷 속도까진 모르지만 인터넷 가능한 곳입니다.
#  USR: 아 네네 거기 목요일 1시 한명 예약해주세요.
#  before: {'관광-종류': '랜드마크', '관광-지역': 'dontcare', '관광-이름': '삼청각', '식당-가격대': 'dontcare', '식당-지역': 'dontcare', '식당-종류': '분식집', '식당-인터넷 가능': 'yes'},
#
#  orange-rice-7839:관광_숙소_식당_12-10
#  VAL: 17:45
#  SYS: 그러시면 치키웨이로 가보시는 건 어떠실까요? 평점이 높기도 하고 가격대도 적당해서 많이들 찾으시더라구요.
#  USR: 아 그래요? 그럼 거기로 가볼게요. 저희가 인원이 많아서 미리 예약을 해야 될 거 같은데, 거기 화요일 5시 45분에 9명으로 예약 될까요?
#  before: {'관광-종류': 'dontcare', '관광-지역': '서울 중앙', '관광-교육적': 'yes', '관광-이름': '그레뱅뮤지엄', '숙소-가격대': 'dontcare', '숙소-종류': '호스텔', '숙소-지역': '서울 중앙', '숙소-흡연 가능': 'no', '숙소-예약 요일': '토요일', '숙소-예약 명수': '9', '숙소-예약 기간': '5', '숙소-이름': '호스텔 제이제이', '식당-가격대': 'dontcare', '식당-지역': '서울 북쪽', '식당-종류': '치킨집', '식당-흡연 가능': 'no'},
#
#  throbbing-wildflower-4147:관광_숙소_식당_10-6
#  VAL: 19:00
#  SYS: 네. 가능하십니다.
#  USR: 그럼 거기로 일요일로 예약해 주세요. 7시에 8명으로요.
#  before: {'관광-종류': '박물관', '관광-지역': '서울 북쪽', '관광-교육적': 'yes', '관광-이름': '대한민국 역사 박물관', '숙소-가격대': '비싼', '숙소-종류': '호텔', '숙소-지역': '서울 동쪽', '숙소-예약 요일': '일요일', '숙소-예약 명수': '8', '숙소-예약 기간': '5', '숙소-이름': '파크 호텔', '식당-가격대': '비싼', '식당-지역': '서울 동쪽', '식당-종류': '양식당', '식당-주차 가능': 'yes'},
#
#  rapid-meadow-2373:숙소_식당_11-7
#  VAL: 20:40
#  SYS: 네, 바로 예약 도와드리겠습니다.
#  USR: 감사합니다. 저 예약 완료되면 예약번호랑 전화번호 좀 알려주세요.
#  before: {'숙소-가격대': 'dontcare', '숙소-종류': '호텔', '숙소-지역': '서울 동쪽', '숙소-인터넷 가능': 'yes', '숙소-스파 유무': 'yes', '숙소-예약 요일': '일요일', '숙소-예약 명수': '2', '숙소-예약 기간': '1', '숙소-이름': '행복 호텔', '식당-가격대': '저렴', '식당-지역': '서울 중앙', '식당-종류': '한식당', '식당-흡연 가능': 'yes'},
#
#  patient-sea-2086:관광_식당_택시_15-5
#  VAL: 20:00
#  SYS: 네, 그럼 제가 예약 도와드릴게요. 예약하고 싶으신 날짜랑 대략적인 시간, 인원 말씀해주시겠어요?
#  USR: 아 잠시만요, 그 화요일에요. 8시에 3명이서 갈 건데 예약 되는지 봐주실래요?
#  before: {'관광-종류': 'dontcare', '관광-지역': '서울 서쪽', '관광-경치 좋은': 'yes', '관광-이름': '하늘공원', '식당-이름': '부찌부찌'},
#
#  curly-hat-7720:식당_숙소_7-1
#  VAL: 18:30
#  SYS: 그럼 용산역 근처에 평점 5점의 한식당 만칠천무한리필을 추천합니다.
#  USR: 아 네 거기로 수요일 18시430분에 4명 예약해주세요.
#  before: {'식당-가격대': '저렴', '식당-지역': '서울 중앙', '식당-종류': 'dontcare'},
#
#  rough-flower-9655:식당_35-0
#  VAL: 17:10
#  SYS:
#  USR: 한시간삼십분식 화요일 다섯시 십분 한명 예약 부탁~
#  before: {},
#
#  morning-dust-7078:식당_12-4
#  VAL: 18:30
#  SYS: 죄송합니다만 원하시는 3시 40분은 예약이 불가 하다고 나옵니다. 혹시 시간을 18시 40분으로 변경하여 예약 해 드려도 될까요?
#  USR: 네 그럼 그렇게 예약해 주세요
#  before: {'식당-가격대': '적당', '식당-지역': 'dontcare', '식당-종류': '일식당', '식당-야외석 유무': 'yes', '식당-예약 요일': '금요일', '식당-예약 시간': '03:40', '식당-예약 명수': '4', '식당-이름': '친구를 만나느라 샵샵샵'},
#
#  white-lake-3885:관광_식당_택시_15-3
#  VAL: 19:40
#  SYS: 네 우선 관광지 전화번호는 1265795355입니다. 네 식당 조회됩니다. 예약 필요하신가요?
#  USR: 아 네 수요일 19시 20분에 4명으로 좀 해주시구요, 가격대는 어떻게 되나요?
#  before: {'관광-종류': 'dontcare', '관광-지역': '서울 북쪽', '관광-경치 좋은': 'yes', '관광-이름': '낙산공원', '식당-이름': '피렌체의밤'}]

# %%
matches
# Out:
# []
